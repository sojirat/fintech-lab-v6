# %% [markdown]
# # Stock Price Prediction
#
# Simple example using moving averages for stock prediction.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Generate sample stock data
dates = pd.date_range('2024-01-01', periods=100)
prices = np.cumsum(np.random.randn(100)) + 100

df = pd.DataFrame({'Date': dates, 'Price': prices})
df['MA_7'] = df['Price'].rolling(window=7).mean()
df['MA_30'] = df['Price'].rolling(window=30).mean()

# Plot
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Price'], label='Price')
plt.plot(df['Date'], df['MA_7'], label='7-day MA')
plt.plot(df['Date'], df['MA_30'], label='30-day MA')
plt.legend()
plt.title('Stock Price with Moving Averages')
plt.show()

print(df.tail())
# Out:
#          Date       Price       MA_7       MA_30
# 95 2024-04-05   98.137931  98.833400  103.138370
# 96 2024-04-06   97.532252  98.390687  102.891565
# 97 2024-04-07   97.145808  97.995285  102.692941
# 98 2024-04-08   98.277527  97.943620  102.504050
# 99 2024-04-09  101.147712  98.432785  102.430265

# %% [markdown]
# ## Analysis
#
# Moving averages help identify trends in stock prices.
