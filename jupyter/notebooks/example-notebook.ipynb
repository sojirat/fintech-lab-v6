# %% [markdown]
# # Welcome to FinTech JupyterLab
#
# This notebook includes examples on data analysis, ML, and blockchain in FinTech.

# %%
import pandas as pd
import numpy as np

print('FinTech Lab Ready!')
# Out:
# FinTech Lab Ready!
