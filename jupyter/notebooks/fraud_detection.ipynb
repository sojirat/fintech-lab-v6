# %% [markdown]
# # Fraud Detection using Isolation Forest
#
# This notebook applies unsupervised learning for detecting anomalies in financial data.

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest
import numpy as np

# Simulated transaction data
data = pd.DataFrame({
    'amount': np.random.normal(100, 20, 200).tolist() + [1000, 1200, 1500],
    'time_diff': np.random.normal(60, 15, 200).tolist() + [5, 10, 2]
})

# Train model
model = IsolationForest(contamination=0.01)
data['anomaly'] = model.fit_predict(data)
print(data.tail())
# Out:
#           amount  time_diff  anomaly
# 198   121.024349  56.184209        1
# 199   120.108750  67.832471        1
# 200  1000.000000   5.000000       -1
# 201  1200.000000  10.000000       -1
# 202  1500.000000   2.000000       -1

# %% [markdown]
# ## Results
#
# Anomalies are marked with -1, normal transactions with 1.
